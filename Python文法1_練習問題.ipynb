# %% [markdown]
# <a href="https://colab.research.google.com/github/aki2181/GCIbase/blob/python/Python%E6%96%87%E6%B3%951_%E7%B7%B4%E7%BF%92%E5%95%8F%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **はじめに**
#
# このノートブックは宿題とは異なり、コードを書いたり、学んだことをアウトプットできる場所を提供するため作成いたしました。 なお、**こちらの練習問題は修了判定に含まれず、提出する必要はございません。**
#
# 解答例の配布は次講義日を予定しております。気になる点や疑問点などは是非受講生の皆さんで助け合い、学びを深めてください。エラー発生時に困ったら、[Pythonよくあるエラーメッセージ10選と対処法](https://www.notion.so/Python-10-2edcfa7cece780578badc2c30ca22ab1?source=copy_link)をご参照ください。

# %% [markdown]
# # **練習問題1. 変数**

# %% [markdown]
# 問1-1. 以下のコードを書き写して実行してください。
#
#
# 変数courseに'GCI_basic_1'を代入
# ```
# course = 'GCI_basic_1'
# course
# ```

# %%
#こちらに書き写してください
course = 'GCI_basic_1'
course
# Out:
# 'GCI_basic_1'

# %% [markdown]
# 変数courseに'GCI_basic_2'を再代入、参照
#
# 変数courseの中が'GCI_basic_1'から'GCI_basic_2'に変化したことを確認
#
# ```
# course = 'GCI_basic_2'
# course
# ```

# %%
#こちらに書き写してください

# %% [markdown]
# 問1-2. 変数courseに'GCI_basic_0'を代入して、出力に表示する時のコードを2パターン挙げました。
# それぞれの？に入る単語を回答してください。
#
# ```
# #パターン1
# course = 'GCI_basic_0'
# ？
# ```

# %%
#答えはこちら
course = 'GCI_basic_0'
course
# Out:
# 'GCI_basic_0'

# %% [markdown]
# ```
# #パターン2
# course = 'GCI_basic_0'
# ？(course)
# ```

# %%
#答えはこちら
course = 'GCI_basic_0'
print(course)
# Out:
# GCI_basic_0

# %% [markdown]
# 問1-3. コードを書いてみよう！
# 変数courseに'GCI_basic_1'を代入して参照によってcourseの値を表示し、
# その後、'GCI_basic_2'を再代入して再度courseの値を表示してください。

# %%
#答えはこちら
course = 'GCI_basic_1'
print(course)
course = 'GCI_basic_2'
course
# Out:
# GCI_basic_1
# 'GCI_basic_2'

# %% [markdown]
# # **練習問題2. 算術演算子**

# %% [markdown]
# 問2-1. 以下のコード部分を書き写して実行してください。
#
#
# ```
# #足し算
# 3 + 5
# ```

# %% [markdown]
# ```
# # 割り算（整数部）
# 100 // 12
# ```

# %%
# 割り算（整数部）
100//12
# Out:
# 8

# %% [markdown]
# ```
# # 割り算（余り）
# 100 % 23
# ```

# %%
# 割り算（余り）
100 % 23
# Out:
# 8

# %% [markdown]
# ```
# # べき乗
# 2 ** 3
# ```

# %%
# べき乗
2**3
# Out:
# 8

# %% [markdown]
# 問2-2a. 以下のコードを実行した結果を答えてください。
#
# ```
# result = 100 - 10 ** 2
# ```

# %%
#答えはこちら
result = 100- 10**2
result
# Out:
# 0

# %% [markdown]
# 問2-2b. 以下のコードを実行した結果を答えてください。
#
# ```
# result = (1 + 1 * 2) * ((1 + 1) * 2) ** 2
# print(result)
# ```

# %%
#答えはこちら

# %% [markdown]
# 問2-3. コードを書いてみよう！
# >あなたはGCI学校3年1組で委員長をしています。
# クラスメイト30人で、お世話になった担任の先生にプレゼントを贈ることにしました🎁
# その先生はコーヒー好きなので、「マグカップ」「インスタントコーヒー」「色紙（寄せ書き用）」を買うことにしました。
# 一人当たり200円を集め、あなたはクラスを代表して買い物に行きました。
#
# >購入品（税込み）:
# >* マグカップ　　　　　　:1,200円 （1個）
# >* インスタントコーヒー　:1,500円 （1箱（30袋入り））
# >* 色紙　　　　　　　　　:300円
#
#
# >(1)購入品の合計金額を計算してください。
# (2)お会計時に新規会員登録で10％オフと伺い、あなたはそのクーポンを利用しました。実際の支払金額を求めてください。
# (3)当初200円ずつ集めましたが、お金が余りました。クラスメイト全員で割り、返金する予定です。一人当たりの返金額と、クラス全員で割り切れるか余りが残らないか確かめてください。

# %%
# (1) 答えはこちら

# %%
# (2) 答えはこちら

# %%
# (3) 答えはこちら

# %% [markdown]
# # **練習問題3. データ型**

# %% [markdown]
# 問3-1. 以下のコード部分を書き写して実行してください。
#
# ```
# # int型（整数）
# age = 10
#
# # type関数で変数ageのデータ型を表示
# type(age)
# ```

# %%
#こちらに書き写してください

# %% [markdown]
# ```
# # float型（小数）
# height = 135.0
#
# # type関数で変数heightのデータ型を表示
# type(height)
# ```

# %%
#こちらに書き写してください

# %% [markdown]
# ```
# # bool型（True）
# A = True
# type (A)
# ```

# %%
#こちらに書き写してください

# %% [markdown]
# ```
# # bool型（False）
# B = False
# type (B)
# ```

# %%
#こちらに書き写してください

# %% [markdown]
# ```
# # str型
# message = 'Welcome to '
# course = 'GCI_basic'
# print (message + course + '!')
# ```

# %%
#こちらに書き写してください

# %% [markdown]
# 問3-2.　以下のコードをstr型からint型に変換してください。？に入るコードを答えてください。
#
#
# ```
# x = '100'
# x = ？
# type(x)
# ```

# %%
#答えはこちら

# %% [markdown]
# 問3-3a.
# >ある大学の文化祭に、お笑い芸人の方がお越しいただけることになりました。講堂でライブが行われます。
# 講堂は収容人数（500人）があるため、当日整理券を配ることになりました。
# 文化祭前日、ライブへの来場希望者数をアンケートしたところ700人いることが分かりました。
#
# >bool型を用いて、来場者が収容人数に収まる場合はTrue、収容できない場合はFalseと表示するコードを書いてください。
#
# >※ヒント:数値を比較する時は比較演算を使用してください。
# 比較演算子は、左右の値を比較する記号であり、True（真）かFalse（偽）のどちらかの値（真偽値）に評価されます。以下、参考の図を添付します。

# %% [markdown]
# <img src="data:image/png;base64,..." width="800">

# %%
#答えはこちら

# %% [markdown]
# 問3-3b.
# >先ほどの文化祭のライブに関して、講演後に感想を入力してもらうことにしました。
# ライブの感想をinput関数を用いて入力してもらうコードを書いてください。
# またprint関数では「感想:○○」と表示してください。

# %%
#答えはこちら

# %% [markdown]
# # **4.総合問題**

# %% [markdown]
# >中学生のA君は、食堂で毎日ご飯を食べています。最近、食べ盛りなためかお昼ご飯で食べる量が増え、お小遣いが足りなくなってきました。
# そこでA君は日々どれぐらいの昼食代を使用しているか、親に説明してお小遣いを増やしてもらう交渉をすることにしました。親から1日500円想定でお小遣いをもらっています。
# 先週のA君が食べたお昼ご飯は以下の通りです。
#
# * 月曜日:カレーライス(400円) + ポテトサラダ(100円) + パン(100円)
# * 火曜日:醤油ラーメン(400円) + ライス大(200円)
# * 水曜日:チキン南蛮(400円) + ライス大(200円)
# * 木曜日:ハンバーグ弁当(500円) + パン(100円)
# * 金曜日:ネギトロ丼(500円) + パン(100円)
#
#
#
# >(1)各曜日での合計金額を求めてください。
# (2)1週間を通しての1日当たりの平均を求めてください。
# (3)bool型を用いて一回の昼食当たり500円想定のお小遣いが足りるかどうか出力してください。（足りる:True、足りない:False）
#
# >※ヒント:数値を比較する時は比較演算を使用してください。

# %%
# (1) 答えはこちら

# %%
# (2) 答えはこちら

# %%
# (3) 答えはこちら

# %% [markdown]
# 以上で第1回目講義の練習問題は終了です。
# お疲れ様でした！
